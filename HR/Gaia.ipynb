# %%
# %run ./gaia_ids.ipynb 
# %run ./gaia_query.ipynb
import pandas as pd
import numpy as np

# %%
# Load list of targets
groups = pd.read_pickle("/home/msp25gd/Downloads/res/meta/groups.pkl")
targets = groups.Sanitised.to_numpy()

# Get Gaia IDs for all targets
print('Getting Gaia IDs for targets....')
Gaia = Gaia_info()
gaia_ids = Gaia.get_gaia_info(targets)
print(gaia_ids)

# Add Gaia info to groups DataFrame
groups_w_gaia = groups.copy()
groups_w_gaia = groups_w_gaia.join(gaia_ids[['Simbad_ID', 'Gaia_ID']])
groups_w_gaia.to_pickle('/home/msp25gd/Downloads/res/meta/groups_w_gaia.pkl')

# Get all Gaia information
print('Getting Gaia info for targets....')
Query = Gaia_Search(gaia_ids)
Query.query_gaia(r = 0.01) # search radius is 0.01 degrees
print(Query.gaia_info)
# Out:
# Getting Gaia IDs for targets....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       6 print('Getting Gaia IDs for targets....')
#       7 Gaia = Gaia_info()
# ----> 8 gaia_ids = Gaia.get_gaia_info(targets)
#       9 print(gaia_ids)
#      11 # Add Gaia info to groups DataFrame
#
# File /tmp/ipykernel_13828/3647423185.py:8, in Gaia_info.get_gaia_info(self, targets)
#       7 def get_gaia_info(self, targets):
# ----> 8     xmatch = self.simbad_xmatch(targets)
#       9     corrected_xmatch = self.rm_duplicates(xmatch)
#      10     return self.join_xmatch(targets, corrected_xmatch)
#
# File /tmp/ipykernel_13828/3647423185.py:13, in Gaia_info.simbad_xmatch(self, targets)
#      12 def simbad_xmatch(self, targets):
# ---> 13     simbad_res = self.gaia_simbad.query_objects(targets)
#      14     if simbad_res is None:
#      15         return pd.DataFrame(columns=['Gaia_ID'])
#
# File /usr/local/python-3.12/lib/python3.12/site-packages/astropy/utils/decorators.py:620, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     617             msg += f"\n        Use {alternative} instead."
#     618         warnings.warn(msg, warning_type, stacklevel=2)
# --> 620 return function(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/astroquery/simbad/core.py:742, in SimbadClass.query_objects(self, object_names, wildcard, criteria, get_query_payload, async_job, verbose, cache)
#     739 for join in joins:
#     740     left_joins.append(_Join(join.table, join.column_left,
#     741                             join.column_right, "LEFT JOIN"))
# --> 742 return self._query(top, columns, left_joins, instance_criteria,
#     743                    from_table=upload_name,
#     744                    get_query_payload=get_query_payload,
#     745                    script_infos=upload)
#
# File ~/.local/lib/python3.12/site-packages/astroquery/simbad/core.py:1628, in SimbadClass._query(self, top, columns, joins, criteria, from_table, distinct, async_job, get_query_payload, **uploads)
#    1624     criteria = ""
#    1626 query = f"SELECT{distinct_results}{top_part}{columns} FROM {from_table}{join}{criteria}"
# -> 1628 response = self.query_tap(query, get_query_payload=get_query_payload,
#    1629                           maxrec=self.hardlimit, async_job=async_job,
#    1630                           **uploads)
#    1632 if len(response) == 0 and top != 0:
#    1633     warnings.warn("The request executed correctly, but there was no data corresponding"
#    1634                   " to these criteria in SIMBAD", NoResultsWarning)
#
# File ~/.local/lib/python3.12/site-packages/astroquery/simbad/core.py:1538, in SimbadClass.query_tap(self, query, maxrec, async_job, get_query_payload, **uploads)
#    1534 if async_job:
#    1535     return self.tap.run_async(query, maxrec=maxrec,
#    1536                               execution_duration=self.timeout,
#    1537                               uploads=uploads).to_table()
# -> 1538 return self.tap.run_sync(query, maxrec=maxrec, uploads=uploads).to_table()
#
# File ~/.local/lib/python3.12/site-packages/pyvo/dal/tap.py:295, in TAPService.run_sync(self, query, language, maxrec, uploads, **keywords)
#     266 def run_sync(
#     267         self, query, *, language="ADQL", maxrec=None, uploads=None,
#     268         **keywords):
#     269     """
#     270     runs sync query and returns its result
#     271
#    (...)    291     TAPResults
#     292     """
#     293     return self.create_query(
#     294         query, language=language, maxrec=maxrec, uploads=uploads,
# --> 295         **keywords).execute()
#
# File ~/.local/lib/python3.12/site-packages/pyvo/dal/tap.py:1204, in TAPQuery.execute(self)
#    1189 def execute(self):
#    1190     """
#    1191     submit the query and return the results as a TAPResults instance
#    1192
#    (...)   1201        for errors parsing the VOTable response
#    1202     """
#    1203     result = TAPResults(
# -> 1204         self.execute_votable(),
#    1205         url=self.queryurl,
#    1206         session=self._session
#    1207     )
#    1208     result.check_overflow_warning(self._client_set_maxrec)
#    1210     return result
#
# File ~/.local/lib/python3.12/site-packages/pyvo/dal/query.py:260, in DALQuery.execute_votable(self, post)
#     235 """
#     236 Submit the query and return the results as an AstroPy votable instance.
#     237 As this is the level where qualified error messages are available,
#    (...)    257 DALQueryError
#     258 """
#     259 try:
# --> 260     return votableparse(self.execute_stream(post=post).read)
#     261 except Exception as e:
#     262     self.raise_if_error()
#
# File /usr/local/python-3.12/lib/python3.12/site-packages/astropy/io/votable/table.py:164, in parse(source, columns, invalid, verify, chunk_size, table_number, table_id, filename, unit_format, datatype_mapping, _debug_python_based_parser)
#     159     config["filename"] = source
#     161 with iterparser.get_xml_iterator(
#     162     source, _debug_python_based_parser=_debug_python_based_parser
#     163 ) as iterator:
# --> 164     return tree.VOTableFile(config=config, pos=(1, 1)).parse(iterator, config)
#
# File /usr/local/python-3.12/lib/python3.12/site-packages/astropy/io/votable/tree.py:4393, in VOTableFile.parse(self, iterator, config)
#    4391 for start, tag, data, pos in iterator:
#    4392     if start:
# -> 4393         tag_mapping.get(tag, self._add_unknown_tag)(
#    4394             iterator, tag, data, config, pos
#    4395         )
#    4396     elif tag == "DESCRIPTION":
#    4397         if self.description is not None:
#
# File /usr/local/python-3.12/lib/python3.12/site-packages/astropy/io/votable/tree.py:4257, in VOTableFile._add_resource(self, iterator, tag, data, config, pos)
#    4255 resource = Resource(config=config, pos=pos, **data)
#    4256 self.resources.append(resource)
# -> 4257 resource.parse(self, iterator, config)
#
# File /usr/local/python-3.12/lib/python3.12/site-packages/astropy/io/votable/tree.py:4040, in Resource.parse(self, votable, iterator, config)
#    4038     self._mivot_block.parse(votable, iterator, config)
#    4039 elif start:
# -> 4040     tag_mapping.get(tag, self._add_unknown_tag)(
#    4041         iterator, tag, data, config, pos
#    4042     )
#    4043 elif tag == "DESCRIPTION":
#    4044     if self.description is not None:
#
# File /usr/local/python-3.12/lib/python3.12/site-packages/astropy/io/votable/tree.py:3982, in Resource._add_table(self, iterator, tag, data, config, pos)
#    3980 table = TableElement(self._votable, config=config, pos=pos, **data)
#    3981 self.tables.append(table)
# -> 3982 table.parse(iterator, config)
#
# File /usr/local/python-3.12/lib/python3.12/site-packages/astropy/io/votable/tree.py:2931, in TableElement.parse(self, iterator, config)
#    2929 elif tag == "BINARY":
#    2930     warn_unknown_attrs("BINARY", data.keys(), config, pos)
# -> 2931     self.array = self._parse_binary(
#    2932         1, iterator, colnumbers, config, pos
#    2933     )
#    2934 elif tag == "BINARY2":
#    2935     if not config.get("version_1_3_or_later"):
#
# File /usr/local/python-3.12/lib/python3.12/site-packages/astropy/io/votable/tree.py:3166, in TableElement._parse_binary(self, mode, iterator, colnumbers, config, pos)
#    3165 def _parse_binary(self, mode, iterator, colnumbers, config, pos):
# -> 3166     careful_read = self._get_binary_data_stream(iterator, config)
#    3168     # Need to have only one reference so that we can resize the
#    3169     # array
#    3170     array = self.array
#
# File /usr/local/python-3.12/lib/python3.12/site-packages/astropy/io/votable/tree.py:3104, in TableElement._get_binary_data_stream(self, iterator, config)
#    3102 def _get_binary_data_stream(self, iterator, config):
#    3103     have_local_stream = False
# -> 3104     for start, tag, data, pos in iterator:
#    3105         if tag == "STREAM":
#    3106             if start:
#
# File /usr/local/python-3.12/lib/python3.12/site-packages/urllib3/response.py:1112, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1109     if len(self._decoded_buffer) >= amt:
#    1110         return self._decoded_buffer.get(amt)
# -> 1112 data = self._raw_read(amt)
#    1114 flush_decoder = amt is None or (amt != 0 and not data)
#    1116 if (
#    1117     not data
#    1118     and len(self._decoded_buffer) == 0
#    1119     and not (self._decoder and self._decoder.has_unconsumed_tail)
#    1120 ):
#
# File /usr/local/python-3.12/lib/python3.12/site-packages/urllib3/response.py:1028, in HTTPResponse._raw_read(self, amt, read1)
#    1025 fp_closed = getattr(self._fp, "closed", False)
#    1027 with self._error_catcher():
# -> 1028     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1029     if amt is not None and amt != 0 and not data:
#    1030         # Platform-specific: Buggy versions of Python.
#    1031         # Close the connection when no data is returned
#    (...)   1036         # not properly close the connection in all cases. There is
#    1037         # no harm in redundantly calling close.
#    1038         self._fp.close()
#
# File /usr/local/python-3.12/lib/python3.12/site-packages/urllib3/response.py:1011, in HTTPResponse._fp_read(self, amt, read1)
#    1008     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#    1009 else:
#    1010     # StringIO doesn't like amt=None
# -> 1011     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /usr/local/python-3.12/lib/python3.12/http/client.py:478, in HTTPResponse.read(self, amt)
#     475     return b""
#     477 if self.chunked:
# --> 478     return self._read_chunked(amt)
#     480 if amt is not None and amt >= 0:
#     481     if self.length is not None and amt > self.length:
#     482         # clip the read to the "end of response"
#
# File /usr/local/python-3.12/lib/python3.12/http/client.py:608, in HTTPResponse._read_chunked(self, amt)
#     605     self.chunk_left = chunk_left - amt
#     606     break
# --> 608 value.append(self._safe_read(chunk_left))
#     609 if amt is not None:
#     610     amt -= chunk_left
#
# File /usr/local/python-3.12/lib/python3.12/http/client.py:648, in HTTPResponse._safe_read(self, amt)
#     641 """Read the number of bytes requested.
#     642
#     643 This function should be used when <amt> bytes "should" be present for
#     644 reading. If the bytes are truly not available (due to EOF), then the
#     645 IncompleteRead exception can be used to detect the problem.
#     646 """
#     647 cursize = min(amt, _MIN_READ_BUF_SIZE)
# --> 648 data = self.fp.read(cursize)
#     649 if len(data) >= amt:
#     650     return data
#
# File /usr/local/python-3.12/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /usr/local/python-3.12/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/python-3.12/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pandas as pd
df = pd.read_pickle('/home/msp25gd/Downloads/res/meta/groups_w_gaia.pkl')
df.head()
# Out:
#    New Groups          OBJECT       Sanitised        Reduced       DEC  \
# 0           0    $\alpha$-Cru    $\alpha$ Cru    $\alpha$cru -63.09899
# 1           1  $\gamma^2$-Vel  $\gamma^2$ Vel  $\gamma^2$vel -47.33665
# 2           2    $\theta$-Car    $\theta$ Car    $\theta$car -64.39407
# 3           3     $\zeta$-Pup     $\zeta$ Pup     $\zeta$pup -40.00284
# 4           4       0003+1713       0003+1713      0003+1713  17.22642
#
#      EXPTIME       MJD-OBS       MJD-END    WAVELMIN    WAVELMAX  SPEC_BIN  \
# 0     5.0078  53747.372964  53747.375327  328.195459  456.300129  0.001358
# 1     5.0079  53670.279645  53670.281882  328.192145  456.299040  0.001357
# 2    10.0084  53686.311039  53686.313337  328.196918  456.298107  0.001356
# 3     5.0081  53670.273791  53670.276006  328.192145  456.299040  0.001357
# 4  1800.0037  59487.233078  59487.254500  328.196045  456.297607  0.002710
#
#    SPEC_RES Simbad_ID Gaia_ID
# 0   65030.0               NaN
# 1   65030.0               NaN
# 2   65030.0               NaN
# 3   65030.0               NaN
# 4   19540.0               NaN

# %%
print(Query.gaia_info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(Query.gaia_info)
#
# NameError: name 'Query' is not defined
