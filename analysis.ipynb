# %%
from astropy.io import fits
import numpy as np
import pandas as pd
#%run constants.ipynb
# %run SNRfilter.ipynb
# Out:
# count    18088.000000
# mean        88.775303
# std        108.373960
# min        -14.826500
# 25%         17.626500
# 50%         56.509904
# 75%        121.366214
# max       2453.173110
# Name: SNR, dtype: float64
# cutoff value (10th percentile): 5.723933539564191
# original rows: 18088
# rows kept in memory (cleaned): 16279
# rows removed in memory: 1809
#                     OBJECT          RA       DEC    EXPTIME       MJD_OBS  \
# 1                HD_137753  232.493530 -52.30335   300.0003  52685.370872
# 2                 HD151852  252.303028  19.29439  1099.9993  60381.365996
# 3                  HD17652   42.272332 -32.40455     4.6984  55434.317453
# 4   SDSS-J013901.40-082443   24.756041  -8.41191  4800.0000  53286.268257
# 5                HIP113086  343.530857  19.89189   480.0038  55784.192984
# 6                Q0439-433   70.321883 -43.22912  3420.0009  52556.268358
# 7                HD 284248   63.650490  22.34940  3000.0001  59858.222586
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # 1) find file/path column in analysis_df
#       2 file_col_candidates = ['FILE', 'file', 'filepath', 'path', 'filename']
# ----> 3 file_col = next((c for c in file_col_candidates if c in analysis_df.columns), None)
#       4 if file_col is None:
#       5     raise ValueError(
#       6         "No file/path column found in analysis_df. Add one (e.g., FILE) so spectra can be opened."
#       7     )
#
# Cell In[8], line 3, in <genexpr>(.0)
#       1 # 1) find file/path column in analysis_df
#       2 file_col_candidates = ['FILE', 'file', 'filepath', 'path', 'filename']
# ----> 3 file_col = next((c for c in file_col_candidates if c in analysis_df.columns), None)
#       4 if file_col is None:
#       5     raise ValueError(
# ...
